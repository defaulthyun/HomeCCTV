# %% [markdown]
# # STEP1 Check and setting env

# %%
# install essential package
# !pip install ultralytics

# %%
# check my env
import torch
print('Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Using torch 2.0.0+cpu CPU

# %%
# check ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.53  Python-3.9.13 torch-2.0.0+cpu CPU
# Setup complete  (8 CPUs, 15.8 GB RAM, 33.2/206.8 GB disk)

# %% [markdown]
# ## Install YOLO8

# %%
# install ultralytics & essential package
# !git clone https://github.com/ultralytics/ultralytics
# !pip install -r ultralytics/requirements.txt --quiet
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.

# %% [markdown]
# # STEP2 Check data

# %%
from PIL import Image

img = Image.open('data/test/images/large_-1-_jpg.rf.3e3e9dd42b61504d23f82da2d8cd36b0.jpg')

img.size[0]
# Out:
# 640

# %% [markdown]
# # STEP3 Train data

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# ^C

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=C:/Users/USER/Desktop/fns/data/data.yaml imgsz=640 epochs=100 batch=16 cache=True device=cpu optimizer=AdamW
# Out:
# Ultralytics YOLOv8.0.53  Python-3.9.13 torch-2.0.0+cpu CPU
# ...
