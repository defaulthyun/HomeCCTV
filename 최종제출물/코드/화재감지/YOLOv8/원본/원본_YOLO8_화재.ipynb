# %% [markdown]
# # STEP1 Check and setting env

# %%
# install essential package
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.9/496.9 KB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 KB 13.4 MB/s eta 0:00:00
# ...

# %%
# check my env
import torch
print('Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Using torch 1.13.1+cu116 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15101MB, multi_processor_count=40)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# check ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.54 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.5/78.2 GB disk)

# %% [markdown]
# ## Install YOLO8

# %%
# install ultralytics & essential package
# !git clone https://github.com/ultralytics/ultralytics
# !pip install -r ultralytics/requirements.txt --quiet
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 6976, done.
# remote: Counting objects: 100% (531/531), done.
# remote: Compressing objects: 100% (220/220), done.
# remote: Total 6976 (delta 366), reused 434 (delta 311), pack-reused 6445
# Receiving objects: 100% (6976/6976), 4.95 MiB | 22.14 MiB/s, done.
# Resolving deltas: 100% (4794/4794), done.

# %% [markdown]
# # STEP2 Check data

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CDZAHlEPRs4p75vXqVQe")
project = rf.workspace("mahmoud-9wyf6").project("fire-and-smoke-detection-ltns0")
dataset = project.version(1).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 KB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 KB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 7.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 10.0 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=7a9d04cbaa7925dd8f2d8554fd3af1fa9d8ac7c6c18d5169a2b703ee1028bec1
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
# ...

# %%
from PIL import Image

img = Image.open('/content/FIRE-AND-sMOKE-DETECTION-1/test/images/10-9-15-2-400_jpg.rf.43ae3fc154458a860fc20a7b3ad5f4b2.jpg')

img.size[0]
# Out:
# 416

# %% [markdown]
# # STEP3 Train data

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# ^C

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=/content/FIRE-AND-sMOKE-DETECTION-1/data.yaml imgsz=416 epochs=100 batch=16 cache=True device=0 optimizer=AdamW
# Out:
# Ultralytics YOLOv8.0.54 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !cp /content/runs/detect/ /content/drive/MyDrive/pt/ -r

# %% [markdown]
# # STEP4 Test

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train3/weights/last.pt source=/content/FIRE-AND-sMOKE-DETECTION-1/test/images/132343342_21n_jpg.rf.c693447552ce34a7fdfc4cce0726f5ef.jpg save=True
# Out:
# Ultralytics YOLOv8.0.54 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/FIRE-AND-sMOKE-DETECTION-1/test/images/132343342_21n_jpg.rf.c693447552ce34a7fdfc4cce0726f5ef.jpg: 416x416 3 Fires, 2 Smokes, 7.9ms
# Speed: 0.4ms preprocess, 7.9ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/predict2
