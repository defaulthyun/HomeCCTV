# %% [markdown]
# # 사용법
#
# - 테스트 폴더 내에 있는 requirement.txt와 데이터의 위치를 ' /content/drive/MyDrive/TEST/ ' 로 지정해 주신후 사용하시면 됩니다!
#
# - 테스트_requirements.txt
#     - /content/drive/MyDrive/TEST/테스트_requirements.txt
#
# - _테스트_데이터
#     - /content/drive/MyDrive/TEST/테스트_데이터

# %%
# !pip install -r /content/drive/MyDrive/TEST/테스트_requirements.txt

# %% [markdown]
# # STEP1 Check and setting env

# %%
# install essential package
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# check my env
import torch
print('Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Using torch 1.13.1+cu116 CPU

# %%
# check ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.54 🚀 Python-3.9.16 torch-1.13.1+cu116 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.5/107.7 GB disk)

# %% [markdown]
# ## Install YOLO8

# %%
# install ultralytics & essential package
# !git clone https://github.com/ultralytics/ultralytics
# !pip install -r ultralytics/requirements.txt --quiet
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 6995, done.
# remote: Counting objects: 100% (550/550), done.
# remote: Compressing objects: 100% (241/241), done.
# remote: Total 6995 (delta 367), reused 441 (delta 308), pack-reused 6445
# Receiving objects: 100% (6995/6995), 4.97 MiB | 13.09 MiB/s, done.
# Resolving deltas: 100% (4795/4795), done.

# %% [markdown]
# # STEP2 Check data

# %%
from PIL import Image

img = Image.open('/content/drive/MyDrive/TEST/테스트_데이터/test/images/10-9-15-2-400_jpg.rf.43ae3fc154458a860fc20a7b3ad5f4b2.jpg')

img.size[0]
# Out:
# 416

# %% [markdown]
# # STEP3 Train data

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=/content/drive/MyDrive/TEST/테스트_데이터/data.yaml imgsz=416 epochs=100 batch=16 cache=True device=cpu optimizer=AdamW
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 70.0MB/s]
# Ultralytics YOLOv8.0.54 🚀 Python-3.9.16 torch-1.13.1+cu116 CPU
# ...
