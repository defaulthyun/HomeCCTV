# %% [markdown]
# # STEP1 ROBOFLOW DATA

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="NhhZ172gBvqmMIO11y69")
project = rf.workspace("can-0ewex").project("istiklal-iha")
dataset = project.version(1).download("yolov5")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 KB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 KB 20.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 9.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=4b47676d6bef6fa3e445c64f147462d6a5b6dca7f9194ebd19fb91f445cd0471
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
# ...

# %% [markdown]
# # STEP2 Install YOLO v5

# %%
# Yolov5 github 레포지토리 clone
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15305, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 15305 (delta 0), reused 2 (delta 0), pack-reused 15300
# Receiving objects: 100% (15305/15305), 14.19 MiB | 21.18 MiB/s, done.
# Resolving deltas: 100% (10493/10493), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 필요한 모듈 설치
# !pip install -U -r /content/yolov5/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 86.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 67.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 102.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 KB 30.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 38.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 44.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 KB 30.2 MB/s eta 0:00:00
# ...

# %%
from glob import glob

# 이미지 경로 list로 넣기
train_img_list = glob('/content/istiklal-iha-1/train/images/*.jpg')
valid_img_list = glob('/content/istiklal-iha-1/valid/images/*.jpg')


# txt 파일에 write
with open('./train.txt', 'w') as f:
	f.write('\n'.join(train_img_list) + '\n')
    
with open('./valid.txt', 'w') as f:
	f.write('\n'.join(valid_img_list) + '\n')

# %%
import yaml



with open('/content/istiklal-iha-1/data.yaml', 'r') as f:
    fire = yaml.load(f, Loader=yaml.FullLoader)

print(fire)
fire['train'] = '/content/train.txt'
fire['val']   = '/content/valid.txt'

with open('/content/istiklal-iha-1/data.yaml', 'w') as f:
    yaml.dump(fire, f)
# Out:
# {'names': ['Fire'], 'nc': 1, 'roboflow': {'license': 'CC BY 4.0', 'project': 'istiklal-iha', 'url': 'https://universe.roboflow.com/can-0ewex/istiklal-iha/dataset/1', 'version': 1, 'workspace': 'can-0ewex'}, 'test': '../test/images', 'train': 'istiklal-iha-1/train/images', 'val': 'istiklal-iha-1/valid/images'}

# %% [markdown]
# # STEP3 Train data

# %%
# !python /content/yolov5/train.py --img 320 --batch 16 --epochs 60 --data /content/istiklal-iha-1/data.yaml --weights yolov5x.pt --name result_fire_2 --cfg /content/yolov5/models/yolov5x.yaml
# Out:
#       59/59      5.27G    0.01337   0.006494          0         33        320: 100% 442/442 [04:18<00:00,  1.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:03<00:00,  2.05it/s]
#                    all        227        416      0.879       0.84      0.877      0.501
#
# 60 epochs completed in 4.347 hours.
# Optimizer stripped from yolov5/runs/train/result_fire_2/weights/last.pt, 172.9MB
# Optimizer stripped from yolov5/runs/train/result_fire_2/weights/best.pt, 172.9MB
#
# Validating yolov5/runs/train/result_fire_2/weights/best.pt...
# Fusing layers...
# YOLOv5x summary: 322 layers, 86173414 parameters, 0 gradients, 203.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 8/8 [00:05<00:00,  1.56it/s]
#                    all        227        416      0.862      0.846      0.888      0.506
# Results saved to yolov5/runs/train/result_fire_2

# %%
# 모델, 모델 결과 위치를 복사하여 이동
# !cp -r /content/yolov5/runs/train/result_fire_2 /content/drive/MyDrive/fire_2

# %%
# 저장된 모델 불러오기
# !cp -r /content/yolov5x.pt /content/drive/MyDrive/fire_2

# %% [markdown]
# # STEP4 Test

# %%
test_img_list = glob('/content/istiklal-iha-1/test/images/*.jpg')

# %%
# !python /content/yolov5/detect.py --source /content/istiklal-iha-1/test/images/Img_1029_jpg.rf.7ab732442c0ba626dcd38f64ec2f5c04.jpg --weights /content/yolov5/runs/train/result_fire/weights/best.pt --img 320 --conf 0.5 --save-txt
# Out:
# detect: weights=['/content/yolov5/runs/train/result_fire/weights/best.pt'], source=/content/istiklal-iha-1/test/images/Img_1029_jpg.rf.7ab732442c0ba626dcd38f64ec2f5c04.jpg, data=yolov5/data/coco128.yaml, imgsz=[320, 320], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 261, in <module>
#     main(opt)
#   File "/content/yolov5/detect.py", line 256, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.9/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
# ...
